# %% [markdown]
# <a href="https://colab.research.google.com/github/rainforest01-coder/ESAA_files/blob/main/MLP_SVM_SVM_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SVM

# %%
import numpy as np
import matplotlib.pyplot as plt


#### Toy Data ####

num_sample = 500

data0 = np.random.randn(num_sample,2) + (1,2)
data1 = np.random.randn(num_sample,2) + (0,-1)

# w1*x1 + w2*x2 - b = 0
data0 = np.hstack([data0,np.ones((num_sample,1),dtype=float)])
data1 = np.hstack([data1,-np.ones((num_sample,1),dtype=float)])

data = np.vstack([data0,data1])

print(data.shape)

X = data[:,:2]
Y = data[:,2]

print(X.shape)
print(Y.shape)

plt.title("Samples")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.scatter(data0[:,0],data0[:,1],s=4,color="b")
plt.scatter(data1[:,0],data1[:,1],s=4,color="r")
plt.show()


class SVM:
    def __init__(self, lam, lr, X, Y):
        self.lam = lam
        self.lr = lr
        self.X = X
        self.Y = Y
        self.W = #### HERE ####
        self.b = #### HERE ####
        self.num_data = #### HERE ####
        print("SVM initialized..")

    # you can freely add additional methods or functions
    # ex. def function(self, a, b, c):
    #         ...
    #         return ...

    # data instance-wise loss and hit computation
    def compute_loss_and_hit(self, x, y):
        #### HERE ####
        return loss, hit

    # data instance-wise gradient computation
    def compute_gradient(self, x, y):
        #### HERE ####
        return (grad_W, grad_b)

    # optimize self.W with simple SGD, i.e., batch_size=1
    # also, compute total loss and training accuracy of current epoch
    def fit(self,num_epoch):
        for epoch in range(num_epoch):
            #### HERE ####
            for ind in range(self.num_data):
            #### HERE ####
            if epoch % 100 == 0:
                print("Epoch: %d, Loss: %.2f, Accuracy: %.3f"%(epoch, total_loss, accuracy))


model = SVM(lam=1.,lr=1e-4,X=X,Y=Y)

model.fit(num_epoch=500)

# draw the optimized linear decision boundary
plt.title("Samples")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.scatter(data0[:,0],data0[:,1],s=4,color="b")
plt.scatter(data1[:,0],data1[:,1],s=4,color="r")
plt.plot([-4, +4], [#### HERE ####,#### HERE ####],color="g")
plt.show()

# %% [markdown]
# # SVM_XOR

# %%
import numpy as np
import matplotlib.pyplot as plt


#### XOR Data ####
# first, use simple SVM and check the classification result
# how can we fix this?

num_sample = 250

data0 = np.random.randn(num_sample,2) + (2,2)
data1 = np.random.randn(num_sample,2) + (-2,-2)
data2 = np.random.randn(num_sample,2) + (2,-2)
data3 = np.random.randn(num_sample,2) + (-2,2)

data0 = np.hstack([data0,np.ones((num_sample,1),dtype=float)])
data1 = np.hstack([data1,np.ones((num_sample,1),dtype=float)])
data2 = np.hstack([data2,-np.ones((num_sample,1),dtype=float)])
data3 = np.hstack([data3,-np.ones((num_sample,1),dtype=float)])

data = np.vstack([data0,data1,data2,data3])

print(data.shape)

X = data[:,:2]
Y = data[:,2]

print(X.shape)
print(Y.shape)

plt.title("Samples")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.scatter(data0[:,0],data0[:,1],s=4,color="b")
plt.scatter(data1[:,0],data1[:,1],s=4,color="b")
plt.scatter(data2[:,0],data2[:,1],s=4,color="r")
plt.scatter(data3[:,0],data3[:,1],s=4,color="r")
plt.show()


class SVM:
    def __init__(self, lam, lr, X, Y):
        self.lam = lam
        self.lr = lr
        self.X = X
        self.Y = Y
        self.W = #### HERE ####
        self.b = #### HERE ####
        self.num_data = #### HERE ####
        print("SVM initialized..")

    # you can freely add additional methods or functions
    # ex. def function(self, a, b, c):
    #         ...
    #         return ...

    # data instance-wise loss and hit computation
    def compute_loss_and_hit(self, x, y):
        #### HERE ####
        return loss, hit

    # data instance-wise gradient computation
    def compute_gradient(self, x, y):
        #### HERE ####
        return (grad_W, grad_b)

    # optimize self.W with simple SGD, i.e., batch_size=1
    # also, compute total loss and training accuracy of current epoch
    def fit(self,num_epoch):
        for epoch in range(num_epoch):
            #### HERE ####
            for ind in range(self.num_data):
            #### HERE ####
            if epoch % 100 == 0:
                print("Epoch: %d, Loss: %.2f, Accuracy: %.3f"%(epoch, total_loss, accuracy))


model = SVM(lam=1.,lr=1e-5,X=X,Y=Y)


model.fit(num_epoch=500)
