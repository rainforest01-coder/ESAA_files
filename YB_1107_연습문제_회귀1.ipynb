# %% [markdown]
# <a href="https://colab.research.google.com/github/rainforest01-coder/ESAA_files/blob/main/YB_1107_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_%ED%9A%8C%EA%B7%801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 단순 선형 회귀 분석**
# - 전복의 나이를 예측하는 선형회귀모델을 생성하세요.
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리 수’를 예측한 뒤, **예측된 ‘껍질의 고리 수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

# %% [markdown]
# **1) 데이터 load 및 변형**

# %%
# 데이터 로드
data = pd.read_csv("abalone.csv")
data.head()
print(data.shape)

# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)
# Out:
# (4177, 9)

# %% [markdown]
# **2) X, y 선택**
# : y는 Rings열, X는 Rings열을 제외한 나머지를 선택하되 전부 실수가 되도록 한다.

# %%
# X,y 데이터 선택
y =data['Rings']

X =data.drop(['Rings'],axis=1)

# %% [markdown]
#  **3) train/test set 분리**

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
train_x, test_x, train_y, test_y=train_test_split(X,y,test_size=0.3)

# %% [markdown]
# **4) 선형회귀모델 생성, 모델 예측치 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import LinearRegression

# %%
#선형회귀모델 생성 및 훈련
lr=LinearRegression()
lr.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
# 모델 예측치 구하기
y_pred=lr.predict(test_x)
# 모델 예측치를 활용해 최종적으로 전복의 나이를 예측
age=y_pred*1.5
age
# Out:
# array([16.31696018, 18.22204393, 11.37905756, ..., 11.7952669 ,
#        11.50765677, 14.88183801])

# %% [markdown]
# **5) 모델 평가: MSE, RMSE, R2 score, corr 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# - MSE, RMSE

# %%
#mse, rmse
mse=mean_squared_error(test_y,y_pred)
rmse=np.sqrt(mse)
print('mse:',mse,'\nrmse:',rmse)
# Out:
# mse: 5.343200736791337
# rmse: 2.3115364450493394

# %% [markdown]
# - R2 score

# %%
#R2 score 측정
r2=r2_score(test_y,y_pred)
print('r2:',r2)
# Out:
# r2: 0.5173814853987486

# %% [markdown]
# - 회귀 절편값

# %%
#회귀 절편 값
print('회귀 절편 값: ',lr.intercept_)
# Out:
# 회귀 절편 값:  3.361079624675731

# %% [markdown]
# - 회귀 계수 값

# %%
#회귀 계수 값
print('회귀 계수 값: ',np.round(lr.coef_,1))
# Out:
# 회귀 계수 값:  [  1.3   7.7  16.9   9.3 -19.8 -11.5   7.8   0.3   0.3  -0.5]

# %% [markdown]
# - 상관계수
#
# Hint: corr 함수 이용.

# %%
# 상관계수 구하기
corr=data.corr()
corr
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# M               0.236543  0.240376  0.215459      0.252038        0.251793
# F               0.309666  0.318626  0.298421      0.299741        0.263991
# I              -0.551465 -0.564315 -0.518552     -0.557592       -0.521842
#
# ...

# %% [markdown]
# # **2. Polynomial features**

# %%
# PolynomialFeatures 라이브러리 호출
from sklearn.preprocessing import PolynomialFeatures

# %%
# 임의 데이터 생성

X = np.arange(6).reshape(3, 2)

df =  pd.DataFrame(X)
df.columns = ['x_1','x_2']
df
# Out:
#    x_1  x_2
# 0    0    1
# 1    2    3
# 2    4    5

# %%
# 차원은 2로 설정
# fit_transform 메소드를 통해 데이터 변환
# PolynomialFeatures로 변환 된 데이터를 데이터 프레임 형태로 변환
pf = PolynomialFeatures(degree=2)
poly = pf.fit_transform(df)
df_poly = pd.DataFrame(poly)
df_poly
# Out:
#      0    1    2     3     4     5
# 0  1.0  0.0  1.0   0.0   0.0   1.0
# 1  1.0  2.0  3.0   4.0   6.0   9.0
# 2  1.0  4.0  5.0  16.0  20.0  25.0

# %%
# df_poly의 컬럼을 1,x1,x2,x1^2,x1*x2,x2^2 로 변경
df_poly.columns=['1','x1','x2','x1^2','x1*x2','x2^2']
df_poly
# Out:
#      1   x1   x2  x1^2  x1*x2  x2^2
# 0  1.0  0.0  1.0   0.0    0.0   1.0
# 1  1.0  2.0  3.0   4.0    6.0   9.0
# 2  1.0  4.0  5.0  16.0   20.0  25.0
