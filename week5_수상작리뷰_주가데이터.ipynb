# %% [markdown]
# <a href="https://colab.research.google.com/github/rainforest01-coder/ESAA_files/blob/main/week5_%EC%88%98%EC%83%81%EC%9E%91%EB%A6%AC%EB%B7%B0_%EC%A3%BC%EA%B0%80%EB%8D%B0%EC%9D%B4%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주식 종료 가격 예측 경진대회
# https://dacon.io/competitions/official/235857/codeshare/4091?page=1&dtype=recent
#
#
# KOSPI-200과 KOSDAQ-150의 주어진 기간 중 마지막으로 거래된 가격(종가) 예측
#
#
# * 데이터 불러오기
# > 코로나 사태로 인해 생긴 골자기 기간을 제거하는 방향으로 주가 데이터 불러오기
#
# ＊ 전처리
# ＞ 주가데이터를 그대로 예측할 시 변동성이 너무 커져 전날 값과의 차이를 예측함
#
# ＞ 주가 지표 추가（주가의 매수와 매도 압력을 알 수 있는ｒｓｉ、 가격의 상대적 높낮이를 판단하는 지표인 볼린저 밴드）
#
# ＞ ｗｅｅｋｄａｙ、 네이버 검색어 트렌드 추가
#
# ＞ 미국장 Ｓ＆Ｐ ５００값 추가
#
# ＞ 코스피、 코스닥 값 추가
#
# ＊ 모델링
# ＸＧＢｏｏｓｔ＋Ａｒｉｍａ ７：３ 앙상블
#
# ＊알게된 점
# － 주가데이터를 그대로 예측할 시 변동성이 너무 커져 전날 값과의 차이를 예측함
# － 주가 지표 추가
# －  네이버 검색어 트렌드 추가 가능

# %%
# s&p 500
# df = DataReader('US500', start='20160104', end='20211206')

sp = pd.DataFrame(sp['Close'])

insert_date = pd.DataFrame(
    index=pd.DatetimeIndex(['2016-01-18 00:00:00', '2016-02-15 00:00:00'])
)
insert_date['Close'] = None

sp = pd.concat([sp, insert_date])
sp = sp.sort_index()
sp = sp.fillna(method='ffill')
sp = sp.loc[pd.DatetimeIndex(data.index), :]
sp.columns = ['SP']
