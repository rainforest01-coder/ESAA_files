# %% [markdown]
# <a href="https://colab.research.google.com/github/rainforest01-coder/ESAA_files/blob/OB/week05%ED%8C%8C%EC%9D%B4%ED%86%A0%EC%B9%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.1 인공지능, 머신러닝과 딥러닝
#
#
# 머신 러닝과 답러닝 모두 학습 모델을 제공하여 데이터를 분류할 수 있는 기술입니다. 하지만 둘
# 은 접근 방식에 차이가 있습니다. 머신 러닝은 주어진 데이터를 인간이 먼저 처리(전처리)합니다.
#
# 머신 러닝은 범용적인 목적을 위해 제작된 것으로 데이터의 특징을 스스로 추출하지 못합니
# 다. 이 과정을 인간이 처리해 주어야 하는 것이 머신 러닝입니다. 즉 머신 러닝의 학습 과정은 각
# 데이터(혹은 이미지) 특성을 컴퓨터(기계)에 인식시키고 학습시켜 문제를 해결합니다. 반면 답러닝
# 은 인간이 하던 작업을 생략합니다. 대량의 데이터를 신경망에 적용하면 컴퓨터가 스스로 분석한
# 후답을찾습니다.
#
# #1.2 머신러닝이란
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 딥러닝이란
#
# 딥러닝이 머신 러닝과 다른 큰 차이점은 인간의 뇌를 기초로 하여 설계했다는 것
#
# ## 딥러닝 모델 학습 과정
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 훈련 단계에서는 한 번에 처리할 데이터%딸 지정합니다. 이때 한 번에 처
# 리해야 할 데이터양이 많아지면 학습 속도가 느려지고 메모리 부족 문제를 야기할 수 있기
# 때문에 적당한 데이터양을 선택하는 것이 중요합니다. 따라서 전체 훈련 데이터셋에서 일정
# 한 묶음으로 나누어 처리할 수 있는 배치와 훈련의 횟수인 에포크 선택이 중요합니다.
#
# ‘훈련 데이터셋 10007H 에 대한 배치 크기가 20’이라면 샘플 단위 20개마다 모델 가중치를
# 한 번씩 업데이트시킨다는 의미입니다. 즉， 총 50 (=1000/20)의 가중치가 업데이트됩니
# 다. 이때 에포크가 10 이고 배치 크기가 20 이라면， 기중치를 50 번 업데이트하는 것을 총 열
# 번 반복한다는 의미입니다. 각 데이터 샘플이 총 열 번씩 사용되는 것이므로 결과적으로 가
# 중치가총 500 번 업데이트됩니다.

# %% [markdown]
# ## 답러닝 학습 알고리즘
#
# 활용분야에 따라지도학습과비지도
# 학습， 전이 학습 강화 학습으로 분류
#
# 1. 지도학습
#
# 이미지 분류는 이미지 또는 비디오상의 객체를 식별하는 컴퓨터 비전 기술입니다. 컴퓨터 비전에
# 서 가장 많이 시용되는 것이 합성곱 신경망(Co nv luti nal Neural Network , C~'N) 입니다. 합성곱 신
# 경망은 목적에 따라 이미지 분류 이미지 인식 이미지 분할로 분류
#
# 시계열 데이터를 분류할 때 사용되는 것이 순환 신경망(RccωuunTe
# 식 데이터처럼 시간에 따른 데이터가 있을 때 순환 신경망을 사용하지만 역전파 과정에서 기울기
# 소멸 문제가 발생하는 단점이 있습니다. 이러한 문제점을 개선하고자 게이트(gate) 를 세 개 추가한
# 것이 바로 LSTM(Long Short-Tcrm Memory) 입니다.
#
# 2. 비지도학습
#
# 드 임베딩과 군집이 있습니다. 자연어(사람의 언어)를 검퓨터가 이해하고 효율
# 적으로 처리하게 하려면 컴퓨터가 이해할 수 있도록 자연어를 적절히 변환히는 것이 필요합니다.
# 이때 워드 임베딩 (word embedcling) 기술을 이용하여 단어를 벡터로 표현(번역에 사용)합니다
#
# 3. 전이학습
#
# 전이 학습(transfer learn ing) 은 사전에 학습이 완료된 모댈 pre -t ained mod 사전 학습 모댈)을 가
# 지고우리가원하는학습에 미세 조정 기법을이용하여 학습시키는방법입니다.
# 사전 학습 모델은 풀고자 하는 문제와 비슷하면서 많은 데이터로 이미 학습이 되어 있는 모댈입니
# 다. 일반적으로 많은 데이터를 구하기도 어렵지만， 많은 데이터로 모델을 학습시키는 것은 오랜
# 시간과 연산량이 필요합니다.

# %% [markdown]
# # 2.1 파이토치 개요
#
# 파이씬 기반의 과학 연산 패키지로 다음 두 집단을 대상으로 합니다.
# * 넘파이를 대체하면서 GPU를 이용한 연산이 필요한 경우
# * 최대한의 유연성과속도를제공하는답러닝 연구플랫폼이 필요한경우
# 하지만 무엇보다 주목받는 이유 중 하나는 간결하고 빠른 구현성에 있습니다.
#
#
# ## 파이토치 특징 및 장점
#
# - GPU에서 텐서 조작 및 동적 신경망 구축이 가능한 프레임워크
#
# -GPU:  연산 속도를 빠르게 하는 역할을 합니다.
# > 딥러닝에서는 기울기를 계산할 때 미분을 쓰는데， GPU를 사용하면 빠른 계산이 가능합니다.  병렬 연산에서 GPU의 속도는 CPU의 속도보다 훨씬 빠르므로 답러닝 학습에서 GPU 사
# 용은 필수라고 할 수 있습니다.
#
# -댄서는 파이토치의 데이터 형태입니다.
# > 텐서는 단일 데이터 형식으로 된 자료들의 다차원 행렬입니다.  텐서는 간단한 명령어(변수 뒤에 . cuda() 를 추개를 시용해서 GPU로 연산을 수행하게
# 할수있습니다.
#
# - 동적 신경망: 훈련을 반복할 때마다 네트워크 변경이 가능한 신경망을 의미합니다. 예를 들
# 어 학습 중에 은닉층을 추가하거나 제거히는 등 모댈의 네트워크 조작이 기능합니다.
#
# ## 파이토치의 아키텍처
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 파이토치 API
#
# 파이토치 API 계층에서는 사용자가 이해하기 쉬운 API를 제공하여 텐서에 대한 처리와 신경망을
# 구축하고 훈련할 수 있도록 돕습니다. 이 계층에서는 사용자 인터페이스를 제공하지만 실제 계산은
# 수행하지 않습니다. 그 대신 C++로 작성된 파이토치 엔진으로 그 작업을 전달하는 역할만 합니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 파이토치엔진
#
# 파이토치 엔진은 Autograd C++, Aten C++, JIT C+十， Python API로 구성되어 있습니다. 먼
# 저 Autograd‘ c++는 가중치， 바이어스를 업데이트하는 과정에서 필요한 미분을 자동으로 계산
# 해 주는 역할
#
# Aten C++는 C++ 댄서 라이브러리를 제공하며 JIT C++는 계산을 최적
# 화하기 위한 JIT(Just ln-Time) 컴파일
#
# ### 연산처리
# 가장 아래 계층에 속하는 C 또는 CUDA 패키지는 상위의 API 에서 할당된 거의 모든 계산을 수행
# 합니다. 여기에서 제공되는 패커지는 CPU와 GPU(TH(토치)， THC(토치 CUDA))를 이용하여 효
# 율적인 데이터 구조 다차원 텐서에 대한 연산을 처리합니다.
#
# -텐서: 그것이 1차원이든 N차원이든 메모리에 저장할 때는 1차원 배열 형태가 휩니다. 즉， 1차원 배열 형태여야만 메
# 모리에 저장할 수 있습니다. 그리고 변환된 차원 배열을 스토리지(storage)라고 합니다. 스토리지를 이해하기 위해
# 서는 오프셋과 스트라이드 개념을 알아야 합니다.
#
# > • 오프셋(offset): 먼서에서 첫 번째 요소가 스토리지에 저장된 인텍스입니다.
# • 스트라이드(stride): 각 차원에 따라 다음 요소를 얻기 위해 건너뛰기(skip)가 필요한 스토리지의 요소 개수입니다.
# 즉， 스트라이드는 메모리에서의 만서 레이아웃을 표현하는 것으로 이해하면 됩니다. 요소가 언속적으로 저장되기 때
# 문에 행 중심으로 스트라이드는 항상 입니다.
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2.2 파이토치 기초 문법
#
# ## 텐서 다루기

# %%
import torch
print(torch.tensor([[1,2],[3,4]]))
print(torch.tensor([[1,2],[3,4]],device='cuda:0'))
print(torch.tensor([[1,2],[3,4]],dtype=torch.float64))
# Out:
# tensor([[1, 2],
#         [3, 4]])
# tensor([[1, 2],
#         [3, 4]], device='cuda:0')
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %%
temp=torch.tensor([[1,2],[3,4]])
print(temp.numpy())
temp=torch.tensor([[1,2],[3,4]],device='cuda:0')
print(temp.to('cpu').numpy())
# Out:
# [[1 2]
#  [3 4]]
# [[1 2]
#  [3 4]]

# %% [markdown]
# ### 텐서의 인텍스조작
#
# 댄서의 인텍스를 조작하는 방법은 여러 가지가 있습니다. 텐서는 념파이의 ndarray를 조작하는
# 것과 유사하게 동작하기 때문에 배열처럼 인텍스를 바로 지정하거나 슬라이스 등을 시용할 수 있
# 습니다.
#
# • torch. FloatTensor: 32 비트의 부동 소수점
# • torch. DoubleTensor: 64 비트의 부동 소수점
# • torch. LongTensor: 64 비트의 부호가 있는 정수

# %%
temp=torch.FloatTensor([1,2,3,4,5,6,7])
print(temp[0],temp[1],temp[-1])
print('-----------------------')
print(temp[2:5],temp[4:-1])
# Out:
# tensor(1.) tensor(2.) tensor(7.)
# -----------------------
# tensor([3., 4., 5.]) tensor([5., 6.])

# %% [markdown]
# 텐서연산및차원조작
#
# 텐서는 넘파이의 ndarray 처럼 다양한 수학 연산이 가능하며 GPU를 사용하면 더 빠르게 연산
# 할수 있습니다. 참고로 텐서 간의 타입이 다르면 연산이 불가능합니다.

# %%
v=torch.tensor([1,2,3])
w=torch.tensor([3,4,6])
print(w-v)
# Out:
# tensor([2, 2, 3])

# %% [markdown]
# 댄서의 차원을 변경하는 가장 대표적인 방법은 view를 이용하는 것입니다. 이외에도 댄서를 결합
# 하는 stack, cat 과 차원을 교환히는 t , transpose도 사용됩니다 view는 넘파이의 reshape과 유
# 사하며 cat은 다른 길이의 댄서를 하나로 병합할 때 사용합니다. 또한 transpose는 행렬의 전치
# 외에도 차원의 순서를 변경할 때도 사용됩나다.

# %%
temp=torch.tensor([[1,2],[3,4]])

print(temp.shape)
print('------------------------------')
print(temp.view(4,1))
print('------------------------------')
print(temp.view(-1))
print('------------------------------')
print(temp.view(1,-1))
print('------------------------------')
print(temp.view(-1,1))
print('------------------------------')
# Out:
# torch.Size([2, 2])
# ------------------------------
# tensor([[1],
#         [2],
#         [3],
#         [4]])
# ------------------------------
# tensor([1, 2, 3, 4])
# ------------------------------
# tensor([[1, 2, 3, 4]])
# ------------------------------
# tensor([[1],
#         [2],
#         [3],
#         [4]])
# ------------------------------

# %% [markdown]
# ### 2.2.2 데이터 준비
#
# -단순 파일 불러오기
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -커스텀 데이터셋을 만들어서 사용
#
# 답러닝은 기본적으로 대량의 데이터를 이용하여 모델을 학습시겁니다. 하지만 데이터를 한 번에
# 메모리에 불러와서 훈련시키면 시간과 비용 측면에서 효율적이지 않습니다. 따라서 데이터를 한 번
# 에 다 부르지 않고 조금씩 나누어 불러서 사용히는 방식이 커스텀 데이터셋(Custom dataset) 입니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -파이토치에서 제공하는 데이터셋 사용
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 모델정의
#
# • 계층(l aycr) : 모률 또는 모률을 구성하는 한 개의 계층으로 합성곱층(ιonvolutional 때-) ， 선형
# 계층(linear layer) 등이 있습니 다.
#
# • 모듈(rnoιlule) : 한 개 이상의 계층이 모여서 구성된 것으로， 모률이 모여 새로운 모률을 만들
# 수도있습니다.
#
# • 모델(mode l) : 최종적으로 원하는 네트워크로 한 개의 모률이 모델이 될 수도 있습니다.
#
#
#
# - nn.Module( )을 상속하여 정으|하는 방법
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Sequential 신경망을 정의하는 방법
#
# nn.Sequential을 사용하면 __ ini t __ ()에서 사용할 네트워크 모텔들을 정의해 줄 뿐만 아니라
# forward( ) 함수에서는 모댈에서 실행되어야 할 계산을 좀 더 가독성이 뛰어나게 코드로 작성할
# 수 있습니다. 또한， Sequential 객제는 그 안에 포함된 각 모률을 순차적으로 실행해 주는데 다음
# 과 같이 코드를 작성할 수 있습니다.

# %%
import torch.nn as nn
class MLP(nn.Module):
  def __init__(self):
    super(MLP,self).__init__()
    self.layer1=nn.Sequential(
        nn.Conv2d(in_channels=3,out_channels=64,kernel_size=5),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(2)
    )

    self.layer2=nn.Sequential(
        nn.Conv2d(in_channels=64,out_channels=30,kernel_size=5),
        nn.ReLU(inplace=True),
        nn.MaxPool2d(2)
    )

    self.layer3=nn.Sequential(
        nn.Linear(in_features=30*5*5,out_features=10,bias=True),
        nn.ReLU(inplace=True),
    )
  def forward(self,x):
    x=self.layer1(x)
    x=self.layer2(x)
    x=x.view(x.shape[0],-1)
    x=self.layer3(x)
    return x
model=MLP()
print('Printing children\n----------------------------')
print(list(model.children()))
print('\n\nPrinting Modules\n')
print(list(model.modules()))
# Out:
# Printing children
# ----------------------------
# [Sequential(
#   (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ), Sequential(
#   (0): Conv2d(64, 30, kernel_size=(5, 5), stride=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# ), Sequential(
#   (0): Linear(in_features=750, out_features=10, bias=True)
#   (1): ReLU(inplace=True)
# )]
#
#
# Printing Modules
#
# [MLP(
#   (layer1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 30, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# ...

# %% [markdown]
# ### 함수로 신경망을 정의하는 방법
#
#  함수로 선언할 경우 변수에 저장해 놓은 계층들을 재사용할 수 있는 장점
#
#   모댈이 복잡해지는 단점도

# %%
def MLP(in_features=1,hidden_features=20,out_features=1):
  hidden=nn.Linear(in_features=in_features,out_features=hidden_features,bias=True)
  activation=nn.ReLU()
  output=nn.Linear(in_features=hidden_features,out_features=out_features,bias=True)
  net=nn.Sequential(hidden,activation,output)
  return net

# %% [markdown]
# ## 모델의 파라미터 정의
#
# • 손실 함수(loss fun<:tion) : 학습하는 동안 출력과 실제 값(정답) 사이의 오차를 측정합니다. 즉，
# wx+ b를 계산한 값과 실제 값인 y의 오차를 구해서 모댈의 정확성을 측정합니다. 손실 함
# 수로 많이 사용되는 것은 다음과 같습니다.
#   • BCELoss: 이진 분류를 위해 사용
#   • CrossEntropyLoss: 다중 클래스 분류를 위해 사용
#   • MSELoss: 회귀 모텔에서 사용
#
#
# • 옵티마이저(optirnizcr) : 데이터와 손실 함수를 바탕으로 모델의 업데이트 방법을 결정합니다.
#
# 다음은 옴티마이저의 주요 특성입니다.
# • optimizer는 step() 메서드를 통해 전달받은 파라미터를 업데이트합니다 .
# • 모델의 파라미터별로 다른 기준(패 학습률)을 적용시킬 수 있습니다.
# • torch.optim.Optimizer(params, defaults)는 모든 옵티마이저의 기본이 되는 클래스입
# 니다.
# • zero_9rad ( ) 메서드는 옵티마이저에 사용된 파라미터들의 기울기(gradient)를 0으로 만듦
#
# • 학습률 스케줄러:  미리 지정한 횟수의 에포크를 지날 때마다 학습률 감소
#
# • 지표(metrics) : 훈련과 테스트 단계를 모니터링합니다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 모델훈련
#
#  학습을 시킨다는 것은y = wx + b라는 함수
# 에서 W와b의 적절한값을찾는다는의미
#
#  가장 먼저 필요한 절차가 optimizer.zero_grad() 메서드를 이용하여 기울기를 초기화
#
#   파이토치는 기울기 값을 계산하기 위해 10ss.
# backwardO 메서드를 이용하는데， 이것을사용하면 새로운 기울기 값이 이전 기울기 값에 누적하여
# 계산
#
# 누적 계산이 펼요하지 않는 모델에 대해서는 불필요합니다. 따라서 기울기 값에 대해 누적 계산이
# 필요하지 않을 때는 입력 값을 모델에 적용하기 전에 optimizer.zerO_9rad() 메서드를 호출하여
# 미분 값(기울기를 구하는 과정에서 미분을 사용)이 누적되지 않게 초기화
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 모델평가
#
#  모댈에 대한 평가는 함수와 모률을 이용
# 하는 두 가지 방법이 있습니다.

# %%
! pip install torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 31.3 MB/s eta 0:00:00
# ...

# %%
import torch
import torchmetrics
# 함수를 이용
preds=torch.randn(10,5).softmax(dim=-1)
target=torch.randint(5,(10,))
acc=torchmetrics.functional.accuracy(preds,target,task='multiclass', num_classes=5)

# %%
import torch
import torchmetrics
metric=torchmetrics.Accuracy(task='multiclass',num_classes=5)
n_batches=10
# 모률을 이용
for i in range(n_batches):
  preds=torch.randn(10,5).softmax(dim=-1)
  target=torch.randint(5,(10,))
  acc=metric(preds,target)
  print(f'Accuracy on batch {i}: {acc}')
acc=metric.compute()
print(f'Accuracy on all data: {acc}')
# Out:
# Accuracy on batch 0: 0.10000000149011612
# Accuracy on batch 1: 0.30000001192092896
# Accuracy on batch 2: 0.4000000059604645
# Accuracy on batch 3: 0.0
# Accuracy on batch 4: 0.30000001192092896
# Accuracy on batch 5: 0.10000000149011612
# Accuracy on batch 6: 0.10000000149011612
# Accuracy on batch 7: 0.0
# Accuracy on batch 8: 0.30000001192092896
# Accuracy on batch 9: 0.4000000059604645
# Accuracy on all data: 0.20000000298023224

# %% [markdown]
#  사이킷런의
# metrics 모률에서 제공하는 confusion_matrix, accuracy_score와 classification_report 클래
# 스를 이용하면 쉽게 정확도 찾을 수 있음

# %% [markdown]
# ## 훈련 과정 모니터링
#
# 파이토치로 머신 러닝/답러닝 모델을 만들어 학습해 보면 학습이 진행되는 과정에서 각 파라미터
# 에 어떤 값들이 어떻게 변화하는지 모나터링하기 어렵습니다. 이때 텐서보드를 이용하면 학습에
# 사용되는 각종 파라미터 값이 어떻게 변화히는지 손쉽게 시각화,성능을 추적하거나 평가
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# • model. train(): 훈련 데이터셋에 사용하며 모델 훈련이 진행될 것임을 알립니다.01때 드롭아웃(dropout)O 1 활
# 성호}됩니다 .
# • model.eval(): 모델을 평가할 때는 모든 노드를 사용하겠다는 의미로 검증과 테스트 데이터셋에 사용합니다.
# mode1.train( )과 mode1.eva1 ( )을 선언해야 모델의 정확도를 높일 수 있습니다.
