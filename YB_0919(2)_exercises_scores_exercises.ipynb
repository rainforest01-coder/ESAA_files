# %% [markdown]
# <a href="https://colab.research.google.com/github/rainforest01-coder/ESAA_files/blob/main/YB_0919(2)_exercises_scores_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}

df = pd.DataFrame(raw_data)
df
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore
# 0      Jason    Miller       0   42             4             25
# 1      Molly  Jacobson       1   52            24             94
# 2       Tina       Ali       1   36            31             57
# 3       Jake    Milner       0   24             2             62
# 4        Amy     Cooze       1   73             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='preTestScore',y='postTestScore',data=df,size='age',sizes=(20,200))
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('preTestScore vs postTestScore')
plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.figure(figsize=(10,10))
df['sex'] = df['female'].map({0: 'Male', 1: 'Female'})
sns.scatterplot(x='preTestScore',y='postTestScore',data=df,size=df['postTestScore']*4.5,hue='sex')
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('preTestScore vs postTestScore')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
#각 사람별 스코어 평균은?
df['mean']=(df['preTestScore']+df['postTestScore'])/2
plt.figure(figsize=(10,10))
sns.barplot(x='first_name',y='mean',data=df)
plt.xlabel("Fist name")
plt.ylabel("Score Mean")
plt.title("Score Mean")
plt.show()
